# %%
person = {
    "name" : "Sumit",
    "class" : "DS",
    "enrollment" : "20260736"
}

# %%
print(person["class"])
# Out:
# DS

# %%
print(person["name"])
# Out:
# Sumit

# %%
print(person.items())
# Out:
# dict_items([('name', 'Sumit'), ('class', 'DS'), ('enrollment', '20260736'), ('marks', 98)])

# %%
# ADD FUNCTION
person["marks"] = 98
print(person)
# Out:
# {'name': 'Sumit', 'class': 'DS', 'enrollment': '20260736', 'marks': 98}

# %%
# TO FIND THE VALUES
print(person["name"])
# Out:
# Sumit

# %%
# TO PERMANETE DELETE THE value
del person["marks"]
print(person)
# Out:
# {'name': 'Sumit', 'class': 'DS', 'enrollment': '20260736'}

# %%
# TO UPDATE THE VALUES
person["name"] = "Atul"
print(person)
# Out:
# {'name': 'Atul', 'class': 'DS', 'enrollment': '20260736'}

# %%
# TO CHECK THE VALUES IN THE DICT
print("marks" in person)
# Out:
# False

# %%
person = {
    "name" : "Sumit",
    "class" : "DS",
    "enrollment" : "20260736"
}

for i in person:
    print(i, person[i])
# Out:
# name Sumit
# class DS
# enrollment 20260736

# %%
print(person.get("marks"))
# Out:
# None

# %%
# UPDATE FUNCTION

person.update({"color" : "Winter white"})
print(person)
# Out:
# {'name': 'Sumit', 'class': 'DS', 'enrollment': '20260736', 'color': 'Winter white'}

# %%
# TO CLEAR THE DICTINOARY

car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car.clear()
print(car)
# Out:
# {}

# %%
# FIND THE STUDENT THEY GOT ABOVE 40%

students = {
    "Sohil" : 50,
    "Sumit" : 90,
    "Atul" : 40,
    "Rahul" : 75,
    "Rohit" : 30
}

for i, j in students.items():
    if j > 40:
        print(j)

# print(students.items())
# Out:
# 50
# 90
# 75

# %%
lst = [2, 4, 3, 6, 7, 2, 5, 9, 1, 5, 3, 7, 5]
dictt = {}

for i in range(0, len(lst)):
    elemt = lst[i]

    if elemt in dictt:
        dictt[elemt] += 1
    else:
        dictt[elemt] = 1

print(dictt)
# Out:
# {2: 2, 4: 1, 3: 2, 6: 1, 7: 2, 5: 3, 9: 1, 1: 1}
